# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,1000,1)
plt.plot(x,x**2)
plt.show()

# %%
x = np.arange(-1000,1000,1)
plt.plot(x,x**2)
plt.show()

# %%
x = np.arange(-1000,1000,1)
plt.plot(x,-x**3+4)
plt.show()
